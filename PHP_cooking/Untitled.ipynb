# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test2 --env MYSQL_USER=test2 --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 9f32a7552192b9c3c1ee9ff6a1f18adb3c791bde41ee1c2855c25142ec4c2976

# %%
! phpstorm project
# Out:
# Info  | RdCoroutineScope          | 14:JobScheduler FJ pool 2/3 | RdCoroutineHost overridden
# 2023-06-21 13:40:02,856 [  26022]   WARN - #c.i.d.PerformanceWatcherImpl - UI was frozen for 5285ms, details saved to /home/student/.cache/JetBrains/PhpStorm2022.2/log/threadDumps-freeze-20230621-134002-PS-222.3739.61-5sec
# 2023-06-21 13:40:06,315 [  29481]   WARN - #c.i.o.a.i.ActionUpdater - 207 ms to call on EDT #update@EditorInspectionsToolbar (com.intellij.codeInsight.actions.ReaderModeActionProvider$createAction$1). Use `ActionUpdateThread.BGT`.
# 2023-06-21 13:40:10,415 [  33581]   WARN - #c.i.u.x.Binding - no accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType
# 2023-06-21 13:40:10,950 [  34116]   WARN - #c.i.d.PerformanceWatcherImpl - UI was frozen for 5778ms, details saved to /home/student/.cache/JetBrains/PhpStorm2022.2/log/threadDumps-freeze-20230621-134010-PS-222.3739.61-5sec
# ...
